# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel('Train_data.xlsx')
data.head(6)
# Out:
#   Warehouse id Region SKU id  2018-04-01 00:00:00  2018-05-01 00:00:00  \
# 0         Wh-1  NORTH  SKU-1                   27                   13
# 1         Wh-1  NORTH  SKU-2                   88                   28
# 2         Wh-1  NORTH  SKU-3                    6                    6
# 3         Wh-1  NORTH  SKU-4                  162                  184
# 4         Wh-1  NORTH  SKU-5                  171                  402
# 5         Wh-1  NORTH  SKU-6                    4                    4
#
#    2018-06-01 00:00:00  2018-07-01 00:00:00  2018-08-01 00:00:00  \
# 0                   30                   14                   22
# 1                  127                  130                   58
# 2                    6                    6                    6
# 3                  110                  172                   90
# 4                  627                  615                  300
# 5                    4                   52                    4
#
# ...

# %%
data_grouped_by_mean = data.groupby(by = 'Warehouse id').mean()
data_grouped_by_mean
# Out:
#               2018-04-01  2018-05-01  2018-06-01  2018-07-01  2018-08-01  \
# Warehouse id
# Wh-1          328.467811  268.618026  256.781116  211.227468  233.253219
# Wh-2          272.471698  263.316038  279.726415  164.141509  151.797170
# Wh-3          141.094156  140.474026  146.584416  123.262987  152.250000
# Wh-4          279.807692  222.391608  185.423077  146.454545  168.818182
#
#               2018-09-01  2018-10-01  2018-11-01  2018-12-01  2019-01-01  ...  \
# Warehouse id                                                              ...
# Wh-1          208.600858  173.300429  354.648069  372.918455  316.184549  ...
# Wh-2          132.834906   86.745283  132.886792  141.132075  126.915094  ...
# Wh-3          144.857143  190.266234  150.603896  163.415584  118.454545  ...
# Wh-4          151.489510  177.118881  183.437063  185.874126  164.531469  ...
#
#               2020-08-01  2020-09-01  2020-10-01  2020-11-01  2020-12-01  \
# Warehouse id
# ...

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)
plt.xlabel("Months")
plt.ylabel("Warehouse - 1 (North)")
plt.xticks(rotation = 75)
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[0,:])
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[0,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,2)
plt.xlabel("Months")
plt.ylabel("Warehouse - 2 (East)")
plt.xticks(rotation = 75)
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[1,:])
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[1,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,3)
plt.xlabel("Months")
plt.ylabel("Warehouse - 3 (West)")
plt.xticks(rotation = 75)
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[2,:])
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[2,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,4)
plt.xlabel("Months")
plt.ylabel("Warehouse - 4 (South)")
plt.xticks(rotation = 75)
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[3,:])
plt.plot(data_grouped_by_mean.columns,data_grouped_by_mean.iloc[3,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])

# %%
# Breaking Year Wise

grouped_2018 = data_grouped_by_mean.iloc[:,0:9]
grouped_2018
# Out:
#               2018-04-01 00:00:00  2018-05-01 00:00:00  2018-06-01 00:00:00  \
# Warehouse id
# Wh-1                   328.467811           268.618026           256.781116
# Wh-2                   272.471698           263.316038           279.726415
# Wh-3                   141.094156           140.474026           146.584416
# Wh-4                   279.807692           222.391608           185.423077
#
#               2018-07-01 00:00:00  2018-08-01 00:00:00  2018-09-01 00:00:00  \
# Warehouse id
# Wh-1                   211.227468           233.253219           208.600858
# Wh-2                   164.141509           151.797170           132.834906
# Wh-3                   123.262987           152.250000           144.857143
# Wh-4                   146.454545           168.818182           151.489510
#
#               2018-10-01 00:00:00  2018-11-01 00:00:00  2018-12-01 00:00:00
# Warehouse id
# Wh-1                   173.300429           354.648069           372.918455
# ...

# %%
grouped_2019 = data_grouped_by_mean.iloc[:,9:21]
grouped_2019
# Out:
#               2019-01-01 00:00:00  2019-02-01 00:00:00  2019-03-01 00:00:00  \
# Warehouse id
# Wh-1                   316.184549           171.115880           727.347639
# Wh-2                   126.915094           129.702830           325.721698
# Wh-3                   118.454545           116.769481           249.990260
# Wh-4                   164.531469           166.174825           293.807692
#
#               2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00  \
# Warehouse id
# Wh-1                   404.540773           306.467811           360.227468
# Wh-2                   327.613208           358.367925           283.051887
# Wh-3                   164.698052           168.422078           167.561688
# Wh-4                   281.895105           256.912587           234.699301
#
#               2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00  \
# Warehouse id
# Wh-1                   251.922747           300.884120           284.746781
# ...

# %%
grouped_2020 = data_grouped_by_mean.iloc[:,21:33]
grouped_2020
# Out:
#               2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00  \
# Warehouse id
# Wh-1                   488.386266           441.493562           309.952790
# Wh-2                   194.547170           232.806604           229.580189
# Wh-3                   144.977273           210.149351           118.194805
# Wh-4                   188.020979           210.248252           162.611888
#
#               2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00  \
# Warehouse id
# Wh-1                    28.845494            96.381974           206.613734
# Wh-2                    10.367925           441.193396           336.570755
# Wh-3                    10.516234            64.292208            86.853896
# Wh-4                    10.041958           176.944056           222.653846
#
#               2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00  \
# Warehouse id
# Wh-1                   311.115880           295.519313           265.549356
# ...

# %%
grouped_2021 = data_grouped_by_mean.iloc[:,33:]
grouped_2021
# Out:
#               2021-01-01 00:00:00  2021-02-01 00:00:00  2021-03-01 00:00:00  \
# Warehouse id
# Wh-1                   423.309013           389.403433           593.673820
# Wh-2                   254.825472           321.509434           423.966981
# Wh-3                   219.545455           188.970779           259.366883
# Wh-4                   227.388112           240.405594           331.244755
#
#               2021-04-01 00:00:00  2021-05-01 00:00:00
# Warehouse id
# Wh-1                    97.304721            95.927039
# Wh-2                   274.886792           164.735849
# Wh-3                    88.032468           170.662338
# Wh-4                   170.202797            59.604895

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)
plt.xlabel("Months")
plt.ylabel("Warehouse - 1 (North)")
plt.xticks(rotation = 75)
plt.plot(grouped_2018.columns,grouped_2018.iloc[0,:])
plt.plot(grouped_2018.columns,grouped_2018.iloc[0,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,2)
plt.xlabel("Months")
plt.ylabel("Warehouse - 2 (East)")
plt.xticks(rotation = 75)
plt.plot(grouped_2018.columns,grouped_2018.iloc[1,:])
plt.plot(grouped_2018.columns,grouped_2018.iloc[1,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,3)
plt.xlabel("Months")
plt.ylabel("Warehouse - 3 (West)")
plt.xticks(rotation = 75)
plt.plot(grouped_2018.columns,grouped_2018.iloc[2,:])
plt.plot(grouped_2018.columns,grouped_2018.iloc[2,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,4)
plt.xlabel("Months")
plt.ylabel("Warehouse - 4 (South)")
plt.xticks(rotation = 75)
plt.plot(grouped_2018.columns,grouped_2018.iloc[3,:])
plt.plot(grouped_2018.columns,grouped_2018.iloc[3,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)
plt.xlabel("Months")
plt.ylabel("Warehouse - 1 (North)")
plt.xticks(rotation = 75)
plt.plot(grouped_2019.columns,grouped_2019.iloc[0,:])
plt.plot(grouped_2019.columns,grouped_2019.iloc[0,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,2)
plt.xlabel("Months")
plt.ylabel("Warehouse - 2 (East)")
plt.xticks(rotation = 75)
plt.plot(grouped_2019.columns,grouped_2019.iloc[1,:])
plt.plot(grouped_2019.columns,grouped_2019.iloc[1,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,3)
plt.xlabel("Months")
plt.ylabel("Warehouse - 3 (West)")
plt.xticks(rotation = 75)
plt.plot(grouped_2019.columns,grouped_2019.iloc[2,:])
plt.plot(grouped_2019.columns,grouped_2019.iloc[2,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])
plt.subplot(2,2,4)
plt.xlabel("Months")
plt.ylabel("Warehouse - 4 (South)")
plt.xticks(rotation = 75)
plt.plot(grouped_2019.columns,grouped_2019.iloc[3,:])
plt.plot(grouped_2019.columns,grouped_2019.iloc[3,:].rolling(window = 4,center = True).mean(),color = "green")
plt.legend(['Simple-Mean','Moving-Average'])

# %%
data_melt = data.melt(id_vars=['Warehouse id','Region','SKU id'],var_name = 'month',value_name = 'sales')
# data.head()
# data_melt = data_melt.sort_values(['month','SKU id'])
data_melt.head(6)
# Out:
#   Warehouse id Region SKU id      month  sales
# 0         Wh-1  NORTH  SKU-1 2018-04-01     27
# 1         Wh-1  NORTH  SKU-2 2018-04-01     88
# 2         Wh-1  NORTH  SKU-3 2018-04-01      6
# 3         Wh-1  NORTH  SKU-4 2018-04-01    162
# 4         Wh-1  NORTH  SKU-5 2018-04-01    171
# 5         Wh-1  NORTH  SKU-6 2018-04-01      4

# %%
data_melt['SKU id'] = data_melt['SKU id'].str.extract('(\d+)',expand = False).astype(int)
# data_melt['Warehouse id'] = data_melt['Warehouse id'].str.extract('(\d+)',expand = False).astype(int)
# data_melt = 
data_melt = data_melt.sort_values(['SKU id','Region','month'])
data_melt.head()
# Out:
#      Warehouse id Region  SKU id      month  sales
# 233          Wh-2   EAST       1 2018-04-01     23
# 1272         Wh-2   EAST       1 2018-05-01     20
# 2311         Wh-2   EAST       1 2018-06-01     11
# 3350         Wh-2   EAST       1 2018-07-01     23
# 4389         Wh-2   EAST       1 2018-08-01     53

# %%
data_melt['sales next'] = data_melt.groupby(['SKU id','Region'])['sales'].shift(-1)
data_melt['sales prev'] = data_melt.groupby(['SKU id','Region'])['sales'].shift(1)
data_melt['sales diff'] = data_melt.groupby(['SKU id','Region'])['sales'].diff(1)
# data_melt[(data_melt['SKU id'] == 1) & (data_melt['Region'] == 'NORTH')].head(10)
data_melt.head(10)
# Out:
#      Warehouse id Region  SKU id      month  sales  sales next  sales prev  \
# 233          Wh-2   EAST       1 2018-04-01     23        20.0         NaN
# 1272         Wh-2   EAST       1 2018-05-01     20        11.0        23.0
# 2311         Wh-2   EAST       1 2018-06-01     11        23.0        20.0
# 3350         Wh-2   EAST       1 2018-07-01     23        53.0        11.0
# 4389         Wh-2   EAST       1 2018-08-01     53         5.0        23.0
# 5428         Wh-2   EAST       1 2018-09-01      5         5.0        53.0
# 6467         Wh-2   EAST       1 2018-10-01      5         5.0         5.0
# 7506         Wh-2   EAST       1 2018-11-01      5        11.0         5.0
# 8545         Wh-2   EAST       1 2018-12-01     11         5.0         5.0
# 9584         Wh-2   EAST       1 2019-01-01      5        11.0        11.0
#
#       sales diff
# 233          NaN
# 1272        -3.0
# 2311        -9.0
# 3350        12.0
# 4389        30.0
# 5428       -48.0
# ...

# %%
data_melt['mean sales 4'] = data_melt.groupby('SKU id')['sales'].rolling(window = 4).mean().reset_index(level = 0,drop = True)  
data_melt['exp mean sales 4'] = data_melt.groupby('SKU id')['sales'].ewm(span=4).mean().reset_index(level = 0,drop = True)  

data_melt['year'] =data_melt['month'].apply(lambda x:x.year).astype(int)
data_melt.head()
# Out:
#      Warehouse id Region  SKU id      month  sales  sales next  sales prev  \
# 233          Wh-2   EAST       1 2018-04-01     23        20.0         NaN
# 1272         Wh-2   EAST       1 2018-05-01     20        11.0        23.0
# 2311         Wh-2   EAST       1 2018-06-01     11        23.0        20.0
# 3350         Wh-2   EAST       1 2018-07-01     23        53.0        11.0
# 4389         Wh-2   EAST       1 2018-08-01     53         5.0        23.0
#
#       sales diff  mean sales 4  exp mean sales 4  year
# 233          NaN           NaN         23.000000  2018
# 1272        -3.0           NaN         21.125000  2018
# 2311        -9.0           NaN         15.959184  2018
# 3350        12.0         19.25         19.194853  2018
# 4389        30.0         26.75         33.857044  2018

# %%
# data_melt['yearly mean'] = 0
# for i in range(len(data_melt)):
#   data_melt.iloc[i,-1] = data_melt[(data_melt['SKU id'] == data_melt.iloc[i,2]) & (data_melt['Region'] == data_melt.iloc[i,1]) & (data_melt['year'] < data_melt.iloc[i,-2]) & (data_melt['month'].month == data_melt.iloc[i,3].month)]['sales'].mean()

# %%
data_melt['is Festival Month'] = data_melt['month'].apply(lambda x: x.month == 1 or x.month == 3 or x.month == 11 or x.month == 12 ).astype(int)
data_melt['is Summer'] = data_melt['month'].apply(lambda x: x.month == 5 or x.month == 6 or x.month == 7 or x.month == 8 ).astype(int)
data_melt['is Winter'] = data_melt['month'].apply(lambda x: x.month == 11 or x.month == 12 or x.month == 1 or x.month == 2 ).astype(int)
data_melt.head(10)
# Out:
#      Warehouse id Region  SKU id      month  sales  sales next  sales prev  \
# 233          Wh-2   EAST       1 2018-04-01     23        20.0         NaN
# 1272         Wh-2   EAST       1 2018-05-01     20        11.0        23.0
# 2311         Wh-2   EAST       1 2018-06-01     11        23.0        20.0
# 3350         Wh-2   EAST       1 2018-07-01     23        53.0        11.0
# 4389         Wh-2   EAST       1 2018-08-01     53         5.0        23.0
# 5428         Wh-2   EAST       1 2018-09-01      5         5.0        53.0
# 6467         Wh-2   EAST       1 2018-10-01      5         5.0         5.0
# 7506         Wh-2   EAST       1 2018-11-01      5        11.0         5.0
# 8545         Wh-2   EAST       1 2018-12-01     11         5.0         5.0
# 9584         Wh-2   EAST       1 2019-01-01      5        11.0        11.0
#
#       sales diff  mean sales 4  exp mean sales 4  year  is Festival Month  \
# ...

# %%
data_melt.reset_index(inplace = True,drop = True)
# train['yearly mean'] = 0
# for i in range(len(train)):
#   train.iloc[i,-1] = train[(train['SKU id'] == train.iloc[i,5]) & (train['Region'] == train.iloc[i,4]) & (train['year'] < train.iloc[i,-4]) & (train['month'] == train.iloc[i,6])]['sales'].mean()
# # test['yearly mean'] = 0
# # for i in range(len(test)):
# #   test.iloc[i,-1] = test[(test['SKU id'] == test.iloc[i,5]) & (test['Region'] == test.iloc[i,4]) & (test['year'] < test.iloc[i,-4]) & (test['month'] == test.iloc[i,6])]['sales'].mean()

# %%
# sum = 0 
data_melt['mean year'] = 0
for i in range(len(data_melt)): 
  itr = i  
  cnt = 0 
  sum = 0
  while (itr >=0) and (data_melt.iloc[itr,1] == data_melt.iloc[i,1]) and (data_melt.iloc[itr,2] == data_melt.iloc[i,2]): 
    sum += data_melt.iloc[itr,4] 
    cnt +=1 
    itr -=12 
  if cnt: 
    data_melt.iloc[i,-1] = (sum/cnt)

# %%
data_melt.fillna(data_melt.mean(),inplace = True)
data_melt.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#       Warehouse id Region  SKU id      month  sales  sales next  sales prev  \
# 39477         Wh-4  SOUTH     434 2021-01-01     12   12.000000        12.0
# 39478         Wh-4  SOUTH     434 2021-02-01     12   12.000000        12.0
# 39479         Wh-4  SOUTH     434 2021-03-01     12   12.000000        12.0
# 39480         Wh-4  SOUTH     434 2021-04-01     12   12.000000        12.0
# ...

# %% [markdown]
# sum = 0
# data_melt['mean year'] = 0
# for i in range(len(data_melt)):
#   itr = i - 12
#   cnt = 0
#   while (itr >=0) and (data_melt.iloc[itr,1] == data_melt.iloc[i,1]):
#     sum += data_melt.iloc[itr,4]
#     cnt +=1
#     itr -=12
#   if cnt:
#     data_melt.iloc[i,-1] = (sum/cnt)

# %%
data_melt.fillna(data_melt.mean(),inplace = True)

warehouse_encode = pd.get_dummies(data_melt['Warehouse id'], prefix = 'Warehouse')
warehouse_encode.head()
region_encode = pd.get_dummies(data_melt['Region'],prefix = 'Region') 
data_melt.drop(labels = ['Warehouse id'],axis =1 ,inplace = True) 
encoded = pd.concat([region_encode,data_melt],axis = 1) 
encoded.reset_index(drop = True,inplace = True) 
encoded.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#    Region_EAST  Region_NORTH  Region_SOUTH  Region_WEST Region  SKU id  \
# 0            1             0             0            0   EAST       1
# 1            1             0             0            0   EAST       1
# 2            1             0             0            0   EAST       1
# 3            1             0             0            0   EAST       1
# ...

# %%
data_melt['mean year'][12]
# Out:
# 29.0

# %%
split_point = '2021-01-01'
train = encoded[encoded['month'] < split_point].copy()
test = encoded[encoded['month'] >= split_point].copy()
# train.rest_index(inplace = True)
len(test)
# train.head()
# Out:
# 5195

# %%
train['month'] = train['month'].apply(lambda x:x.month).astype(int)
test['month'] = test['month'].apply(lambda x:x.month).astype(int)
train.head()
# test['month'] = test['month'].apply(lambda x:x.month).astype(int)
# Out:
#    Region_EAST  Region_NORTH  Region_SOUTH  Region_WEST Region  SKU id  month  \
# 0            1             0             0            0   EAST       1      4
# 1            1             0             0            0   EAST       1      5
# 2            1             0             0            0   EAST       1      6
# 3            1             0             0            0   EAST       1      7
# 4            1             0             0            0   EAST       1      8
#
#    sales  sales next  sales prev  sales diff  mean sales 4  exp mean sales 4  \
# 0     23        20.0  219.313243   -3.404859    218.429315         23.000000
# 1     20        11.0   23.000000   -3.000000    218.429315         21.125000
# 2     11        23.0   20.000000   -9.000000    218.429315         15.959184
# 3     23        53.0   11.000000   12.000000     19.250000         19.194853
# 4     53         5.0   23.000000   30.000000     26.750000         33.857044
#
# ...

# %%
train.head(
    
)
# Out:
#    Region_EAST  Region_NORTH  Region_SOUTH  Region_WEST Region  SKU id  month  \
# 0            1             0             0            0   EAST       1      4
# 1            1             0             0            0   EAST       1      5
# 2            1             0             0            0   EAST       1      6
# 3            1             0             0            0   EAST       1      7
# 4            1             0             0            0   EAST       1      8
#
#    sales  sales next  sales prev  sales diff  mean sales 4  exp mean sales 4  \
# 0     23        20.0  219.313243   -3.404859    218.429315         23.000000
# 1     20        11.0   23.000000   -3.000000    218.429315         21.125000
# 2     11        23.0   20.000000   -9.000000    218.429315         15.959184
# 3     23        53.0   11.000000   12.000000     19.250000         19.194853
# 4     53         5.0   23.000000   30.000000     26.750000         33.857044
#
# ...

# %%
def mape(y_true,y_pred):
  ape = np.abs((y_true-y_pred)/y_true)
  ape[~np.isfinite(ape)] = 1
  return np.mean(ape)

# %%
print(len(test.columns))
print(len(train.columns))
# Out:
# 18
# 18

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators = 100,random_state = 0)
Xtr = train.drop(['SKU id','sales next','Region','mean year'],axis = 1)
Ytr = train['sales next']
# Xtr = train.drop(['sales','Region','sales diff'],axis = 1)
# Ytr = train['sales']
model.fit(Xtr,Ytr)
# Out:
# RandomForestRegressor(random_state=0)

# %%
Ytrue = test['sales next']
Ypred = model.predict(test.drop(['SKU id','sales next','Region','mean year'],axis = 1))
# Ytrue = test['sales']
# Ypred = model.predict(test.drop(['sales','Region','sales diff'],axis = 1))
mape(Ytrue,Ypred)
# Out:
# 3.788958590757736

# %%
test['pred'] = Ypred
# plt.plot(test['sales next'])
# plt.plot(test['pred'])

# %%
test.reset_index(inplace = True)
test.sort_values(['SKU id'],inplace = True)

# %%
test1 = test[test['month'] == 1 ]
test2 = test[test['month'] == 2 ]
test3 = test[test['month'] == 3]
test4 = test[test['month'] == 4]
test1.reset_index(inplace = True)
test2.reset_index(inplace = True)
test3.reset_index(inplace = True)
test4.reset_index(inplace = True)

# %%
plt.figure(figsize = (18,12))
plt.subplot(2,2,1)
plt.plot(test1['SKU id'],test1['sales next'])
plt.plot(test1['SKU id'].values,test1['pred'].values)
plt.title('January')
plt.subplot(2,2,2)
plt.legend(['True','Predicted'])
plt.plot(test1['SKU id'],test2['sales next'])
plt.plot(test1['SKU id'],test2['pred'])
plt.title('February')
plt.legend(['True','Predicted'])
plt.subplot(2,2,3)
plt.plot(test3['SKU id'],test3['sales next'])
plt.plot(test3['SKU id'],test3['pred'])
plt.title('March')
plt.subplot(2,2,4)
plt.legend(['True','Predicted'])
plt.plot(test4['SKU id'],test4['sales next'])
plt.plot(test4['SKU id'],test4['pred'])
plt.title('April')
plt.legend(['True','Predicted'])

# %%
df = test1[['SKU id','Region','sales next','pred']]
df.columns = ['SKU id','Region', 'jan sales next', 'jan pred']
df['feb sales next'] = test2['sales next']
df['feb pred'] = test2['pred']
df['march sales next'] = test3['sales next']
df['march pred'] = test3['pred']
df['april sales next'] = test4['sales next']
df['april pred'] = test4['pred']
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#    SKU id Region  jan sales next  jan pred  feb sales next  feb pred  \
# 0       1   EAST            11.0     85.44           135.0    220.90
# 1       1   WEST           288.0    129.19            73.0    415.14
# 2       1  SOUTH            76.0    488.88            16.0     50.68
# 3       1  NORTH            14.0     19.11             5.0    107.76
# 4       2   WEST           115.0    126.46            74.0     41.38
#
#    march sales next  march pred  april sales next  april pred
# 0              87.0       21.23             117.0      128.18
# 1             112.0       76.66              19.0      244.61
# 2               8.0       18.99              12.0       19.22
# 3               5.0       26.33               5.0       23.91
# 4              30.0       44.94              50.0       70.65

# %%
# model = RandomForestRegressor(n_estimators = 100,random_state = 0)
# Xtr = train.drop(['sales next','SKU id','Region'],axis = 1)
# Ytr = train['sales next']
# model.fit(Xtr,Ytr)

# %%
# Ytrue = test['sales next']
# Ypred = model.predict(test.drop(['sales next','SKU id','Region'],axis = 1))
# mape(Ytrue,Ypred)
